# %%
from langchain_community.document_loaders import TextLoader, DirectoryLoader
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.documents import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_chroma import Chroma
from pathlib import Path
from dotenv import load_dotenv
# Out:
# /var/folders/yd/_m8_59617mj2h9bql97_j64r0000gn/T/ipykernel_3785/2047418069.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader, DirectoryLoader

# %%
# load the api keys
load_dotenv()
# Out:
# True

# %%
# create the llm and embedding model

llm = ChatOpenAI(model="gpt-5-mini")

embedder = OpenAIEmbeddings(model="text-embedding-3-small",
                            dimensions=1024) # 1536

# %%
# load the docs from source

loader = DirectoryLoader(path=Path("./cleaned-transcripts/").as_posix(),
                         loader_cls=TextLoader,
                         show_progress=True)

docs = loader.load()
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 1280.83it/s]

# %%
docs[0].page_content[0:1000]
# Out:
# "Pakistan, Ahmedabad, Patna, Dheradoon, Subodh, where are you from? I am from Dheradoon too.\nYou are from Kharrawala, you are from Kharwala, I am from Miawala\nCome on, perfect\nOkay, let's begin\nFirst of all, I will introduce myself\nHas anyone seen me or taken any course of mine before?\nAnyone? Yes or no please?\nOkay, fine\nNo worries, let me tell you about myself\nI am Ajay, I belong to Uttarakhand\nAnd I have been working with CampusX for the last two years\nI am working on the Data Analytics and AI part on CampusX\nAnd in the last two years, I have delivered multiple courses like\nOLAMA, Data Analytics, Mentorship Program, Gemini, Power BI and many more\nAnd I will be taking most of your AI Pulse sessions\nRight? So currently, I am working with CampusX\nAnd I am doing my doctorate in frugal AI\nNow, coming to the session\nToday's session is going to be on AI Pulse\nWhat are we going to do in this session?\nIn this session, we are going to talk about\nWhat are we going to do in this session?\nWhat is"

# %%
# chunk the text

chunker = RecursiveCharacterTextSplitter(chunk_size=500,
                                         chunk_overlap=50)

chunks = chunker.split_documents(docs)

# %%
print(f"Chunks: {len(chunks)}")
# Out:
# Chunks: 542

# %%
# vector store

vs = Chroma(collection_name="rag_demo",
            embedding_function=embedder,
            persist_directory=Path("./saved-embeddings").as_posix())

# add docs

vs.add_documents(chunks)
# Out:
# ['fed54d8c-cdc8-430b-b50b-cdb75465f02f',
#  '78ba0073-647c-4a06-8aa0-df0505b4164d',
#  '8ef0629c-2d4c-4e16-93dd-352319ad8926',
#  'a6119c6b-807e-42d4-9102-9d68d450f3dd',
#  'fb5eb762-4305-4f16-bd29-5ee5845047eb',
#  '48b578ab-1b3a-4658-a267-edbffe8b0463',
#  '92ce40fe-5c06-4677-b980-dc83a56b606b',
#  '43036589-8db0-4e07-8336-4baf00ecfced',
#  'fdfb3d22-2d57-4789-b4c1-8cc8480ee980',
#  '236b9407-908a-4d0b-b9ad-d60f652a4cf7',
#  'fa63b8bc-235f-453d-9fdd-768f8e2fe799',
#  'e66600ed-9751-4b4f-8f06-7d76e803e560',
#  '5b7edf67-6909-4a99-b63b-53cf103cd965',
#  '8857e799-2287-40d5-b01f-4770c7edbd5d',
#  'e9b60ea6-c939-40cb-ab23-33b82472fd5f',
#  'e1a2767d-9437-4bf5-ae24-43d8196c8f25',
#  'c10544dc-beda-40ab-9923-93d747cb24e5',
#  'ae08bd54-7c22-4a74-a749-f343d6bcd6c8',
#  '15e4e5ff-82ff-4839-afd6-c41e3d995a77',
#  'a40f8e82-9ef8-44ed-b22c-61c1c3d64f31',
#  'd91b55c5-3c76-4264-94c7-bd4027a250a0',
#  '2b5d3c34-a7b6-4b61-a0e5-6b9316a7546b',
#  '7cd85114-e268-45a2-88ae-5aa06726bea5',
#  '52cf443f-003f-4e4e-933c-adacecc7c861',
#  '0e3fd2b9-2b88-4134-8475-3656b277bf3c',
#  '6a402afb-789d-40a2-a4ef-4a532e115e4d',
#  'fb106e65-eb59-45ac-bd8c-b468c995e87c',
#  '52b29de0-f8a6-4ee1-900e-ab5efe5c35f8',
#  '1fd361c3-08aa-46f0-823f-98195939adb8',
#  '4c607927-72c9-454e-b91d-135525f35829',
#  '2b997122-a897-4b66-92b2-fe3986fdf27d',
#  '9b1d9b2a-02ef-4dd9-a1b9-85094fac27a0',
#  '8c962e1c-de40-4b36-add4-996ff4d1a8ad',
#  '35235cf0-72b7-4859-9af1-72e309ffad0c',
#  'd8795964-fd97-40ff-8d49-f2db0bc270eb',
#  '182e27e1-f845-4390-8476-c7cd8d5b19db',
#  '85ab6e73-219a-41d0-8561-97a956291207',
#  'e65dca4d-044c-4b7e-9db7-63df61f5a212',
#  'a2f3a0a1-14d9-45bd-9cb6-964da8ffcdba',
#  'c03477c7-f235-4a5a-8f61-d642d8a697bd',
#  '91fbe7fc-bbf3-4cc0-8306-7312bcd769d3',
#  '2407816d-9736-480e-b08b-7b6aced78576',
#  '2da71be2-351d-4d2f-9a71-b6f5d5b72c25',
#  'ca0c75f9-ee76-458b-805c-3c4634561fb5',
#  '2ecfe9ae-a76e-4a55-95bd-39defada0405',
#  '2079a2b8-24a3-4b73-b1d9-4d4415a4db20',
#  'f15d41fb-69be-48c4-b348-83c531f9c254',
#  'f13ca4f1-0fd9-4659-8019-ac0ae32a778d',
#  'd3430da9-bf9d-4b77-a836-055186225e8c',
#  'bb2bde47-cbde-4ad7-b190-882d4bcbbc52',
#  '3a4ee08d-36ea-4fb7-85fc-0031bc16f504',
#  '4ab5d006-4e65-4a4d-b578-e6bff611de44',
#  '5747bfe0-6a79-4e1b-94b6-14c645afe3d1',
#  'a4544e28-72d0-4c0c-ac99-d0514a2f2f7d',
#  '8c4d8718-c26e-45bc-9159-53eb3efa9599',
#  'fff49cc6-782e-4d76-81a2-fd546f8f79e3',
#  '8cd33b9f-6582-4669-8813-252a5510c0ec',
#  '1e9e596a-2a63-45d8-8f19-c48bfb04d52c',
#  'd44a80d7-05d4-43c0-9778-8f58eb920611',
#  'd0d3fee8-3111-4c99-b43d-e3ab9870df13',
#  'db640b17-cca6-4515-886c-7e6afcad03cc',
#  'ef45de5d-20ca-4df4-afe4-8fc3877b4549',
#  'a8959f77-7a73-4a1c-bb87-d6cd53b8bdcb',
#  '9716591d-7fa9-4f7b-8177-d8ab8b2108d2',
#  'afaa65dd-8354-408c-b93d-96081a6da470',
#  'e30b1f5a-c029-4be6-8879-c4b08dd6d976',
#  '3e1e7305-5da9-49df-8c0b-b8494d7d2d40',
#  'd8ac3866-99ef-465e-b1e7-f7a909ca1269',
#  '66165567-8730-4374-b763-f7fc795ee885',
#  '967c0daa-9eef-43af-b764-7a8763e14a98',
#  '0d546ef4-434e-454c-b914-c62b8d1c98fd',
#  '94de9548-3271-484d-9949-61a51947ab2e',
#  '36133234-3cee-46ba-b157-43b5d27efdd0',
#  'aba59c86-c39e-44db-bbe8-6a1205de81c0',
#  'eaf8661e-6f44-43da-9ded-8f7458921718',
#  '571df958-c548-4a24-9c1b-0515c57b391b',
#  'c110cafb-5a13-49b7-9b62-d666b7c4f4cc',
#  '00e2efc9-b075-4802-95f9-e7463f936b48',
#  '4ec1de57-7e96-4273-88d9-6fb233eef7c6',
#  '8583c8ec-9ae5-418d-a159-ee20343cd0c5',
#  '594a02e8-4abf-43ea-9de6-549890fe207e',
#  '7e3910c6-d417-4ada-93b4-b874dcea2c3c',
#  'ad39568e-f8f3-40ae-bf17-2da140327e34',
#  'c4a81917-6cf1-4f08-ba99-b98d92a0c085',
#  '66232b88-e588-4b1f-9467-4f03a2fc801e',
#  'fb5639ac-e2e8-4bca-98d5-b0ffe52a5e14',
#  '2ed3f16b-8519-493a-a5d3-a0858fb39d1f',
#  'a4b08857-ba5a-47bd-a731-e3d29370e104',
#  '58886ece-0e26-46d0-a138-e1f77dae32d8',
#  '2b2a8243-3afe-49d8-8a2d-e22c259eac60',
#  '09e90211-af21-495e-88d5-4fd8fba46e95',
#  '04bcdc46-9e03-4c72-9975-45a3663b8a53',
#  'a37a2a5f-df8c-440b-a98d-168322b4e365',
#  '3782cc6c-11e9-4098-b83c-08668f1e68c8',
#  '38bc485a-793c-43ba-9ccb-b7cf8874e04f',
#  'd0c1e76e-a0ac-49da-9d7b-4316ee75b185',
#  '1b5d394d-620b-431c-aa64-0bfbba84fa37',
#  '95d577ce-f422-465f-801f-1011d4f79503',
#  '8773a311-c9f9-44b3-acfc-d3855fefb734',
#  'e68d262a-f540-40bd-a74f-8685487ee7f9',
#  '5a81a753-7c94-4fc4-ab5b-f69f31d55b6d',
#  '274a5b94-ea80-40b4-b68b-6b99bffafd43',
#  'e57c2a85-c643-4766-a32b-afc961f6f586',
#  '1b3695bc-0fb0-4d81-9519-e5c26bc88635',
#  'fbe51856-9e0b-45b6-8e39-2e052877124d',
#  '866046a1-3b92-4129-8336-e14125298bbf',
#  '67fd066b-3cf9-4645-8a34-1b338d59f446',
#  'cb0b9437-0e10-4a64-b90c-aa9dd8b21b63',
#  '5680ad9b-5304-44f6-ba70-03761504b7c9',
#  '67fb4abc-cf8a-4bdb-be64-84ad74cdb309',
#  '73ed4667-162a-443b-9769-b96a0fe5f87f']

# %%
# create the retriever

retriever = vs.as_retriever(search_kwargs={"k":3})

# %%
from langgraph.graph import StateGraph, START, END
from typing import Literal, TypedDict

# %%
class RAGState(TypedDict):
    
    query: str 
    retrieved_docs: list[Document]
    context: str 
    prompt: ChatPromptTemplate
    response: str

# %%
def retrieve(state: RAGState) -> dict:
    query = state["query"]
    retrieved_docs = retriever.invoke(query)
    
    context = "\n\n".join([doc.page_content for doc in retrieved_docs])
    return {"retrieved_context":retrieved_docs,
            "context":context}

# %%
def augmentation(state: RAGState) -> dict:

    prompt = ChatPromptTemplate.from_messages([
        ("system", """You are a helpful assistant. Answer the user query
                      based on the given context only. If you do not know the answer
                      say I don't know. Do not add any preamble to the response"""),
        ("human", "context: {context}\n\nquery: {query}")
    ])
    
    return {"prompt": prompt}

# %%
from langchain_core.output_parsers import StrOutputParser

# %%
def generation(state: RAGState) -> dict:
    
    query = state["query"]
    context = state["context"]
    prompt = state["prompt"]
    
    rag_chain = prompt | llm | StrOutputParser()
    response = rag_chain.invoke({"context":context, "query":query})
    
    return {"response":response}

# %%
# create the graph
graph_builder = StateGraph(RAGState)

graph_builder.add_node("retrieve", retrieve)
graph_builder.add_node("augmentation", augmentation)
graph_builder.add_node("generation", generation)

graph_builder.add_edge(START,"retrieve")
graph_builder.add_edge("retrieve","augmentation")
graph_builder.add_edge("augmentation","generation")
graph_builder.add_edge("generation",END)

graph = graph_builder.compile()

# %%
graph

# %%
result = graph.invoke({"query": "how much fine was imposed on the lawyer who used fake evidences from chatgpt"})

# %%
print(result["response"])
# Out:
# Around $5,000.

# %%
result["context"]
# Out:
# "Launching their IPO\nOkay?\nSo, early June 2026\nthe artificial intelligence industry\nhas taken a very turn\nyou can say, a very crazy turn\nWhat was the turn?\nThat two very dominant companies in the AI firm\nin the AI landscape\nOpenAI and Entropic\nthey have filed their IPO\nRight?\nMeans, these companies\nthey are planning to move public\nCheck it\nThe IPO filed by OpenAI\nhas been filed at a valuation of 1 trillion dollars\nAnd the IPO filed by Entropic\nhas been filed at a valuation of 965 billion dollars\n\nSo, this is the news\nNow, let's do one thing\nLet's deep dive this news\nLet's do its post-mortem\nRight?\nFirst of all, let's understand\nthat these companies\nAI Labs\nRight?\nThese AI Labs have been existing for a long time\nSo, why is the need to file IPO now?\nOkay?\nIf I talk about OpenAI\nOpenAI is a very old AI Lab\nNow, why is it filing IPO?\nOkay?\nSo, what are the reasons?\nIs it a catalyst?\nRight?\nBecause of which\nthese companies are filing their IPO\nOkay?\nLet's understand that\n\nFrom what products\nFrom what model\nSo then people will actually know\nThat is AI actually earning money\nAnd giving it or not\nAI is just burning money\nRight?\nPeople will know then\nIf this IPO becomes your success\nAgain there is money in AI\nAgain if IPO fails\nThere is no money in AI\nWhen companies will release their findings or finances\nQuarterly, yearly\nAgain these are norms\nThat if you are taking money from the public\nThen you have to tell the public everything\nSo there actually you will know"
